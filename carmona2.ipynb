# %% [markdown]
# <a href="https://colab.research.google.com/github/jdieramon/acarmona/blob/main/carmona2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Number of SNP markers in the VCF file

# %%
cat(system("egrep -v '^#' Chickpea.MCR50.snps.vcf | wc -l", intern = TRUE), sep = '\n')
# Out:
# 5891

# %%
plot(rnorm(20), rnorm(20), col = 'blue')
# Out:
# plot without title

# %% [markdown]
# # New Section
