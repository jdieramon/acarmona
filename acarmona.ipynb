# %% [markdown]
# <a href="https://colab.research.google.com/github/jdieramon/acarmona/blob/main/acarmona.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Make a plot

# %%
plot(rnorm(30), rnorm(30), col = 2, pch = 19)
# Out:
# plot without title
